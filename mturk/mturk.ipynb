# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook will walk you through creating and monitoring your HITs.
#
# It provides methods to create HITs, pretty-print HIT and assignment status, expire/edit HITs, create qualifications, and download collected data.
#
# Before continuing, make sure that you have read the README and set all config fields to their desired values.
#
# ## Requirements:
#
# This code requires Python3 and the following packages:
# - boto3
# - beautiful soup 4
#
# Before using, you will have to set up an authentication key to use the Amazon API and include it in a credentials file. See here: https://aws.amazon.com/developers/getting-started/python/

# %% [markdown]
# # Setup

# %% [markdown]
# Read the config file and establish a connection to MTurk.
#
# A connection is made to production or to the sandbox based on values in the config.

# %%
import datetime
import boto3
import json
import copy
import pprint
from bs4 import BeautifulSoup as bs 
from uuid import uuid4
from Naked.toolshed.shell import muterun_js
import json
import math
from IPython.core.display import display, HTML

# %%
# Sandbox or Production? You only spend money in Production.
USING_PROD = True

# Safety flags that prevent you from accidentally messing up your HITs. 
# Set to False except when you are performing these specific tasks.
ALLOW_HIT_CREATION = True
ALLOW_ASSIGNMENT_ADDITION = False
ALLOW_CREATE_QUAL = True
ALLOW_UPDATE_EXPIRATION = False

# %%
if USING_PROD:
    print("USING PROD")
    endpoint_url = 'https://mturk-requester.us-east-1.amazonaws.com'
    origin="production"
else:
    print("USING SANDBOX")
    endpoint_url = 'https://mturk-requester-sandbox.us-east-1.amazonaws.com'
    origin="sandbox"

session = boto3.session.Session(profile_name='default')
cl = session.client('mturk', region_name='us-east-1', endpoint_url=endpoint_url)
# Out:
# USING PROD

# %% [markdown]
# # Make new HIT

# %%
# List of qualifications that you will use to filter potential workers. 
# These require that workers come from the US and have an approval rating >= 95%
# Edit this list to specify different qualifications for workers 
QUALS = [
    {
        'QualificationTypeId': '00000000000000000071',
        'Comparator': 'EqualTo',
        'LocaleValues': [{
            'Country': 'US',
        }],
    },
    {
        'QualificationTypeId': '000000000000000000L0',
        'Comparator': 'GreaterThanOrEqualTo',
        'IntegerValues': [
            95
        ],
    },
]

# %%
# generic helper that sets metadata fields based on the config file.
def create_hit(task, questionText, quals=QUALS): 
    if ALLOW_HIT_CREATION:
        response = cl.create_hit(
            Title=task['title'],
            Description=task['description'],
            Keywords=','.join(task['keywords']),
            MaxAssignments=task['numAssignments'],
            Reward=task['rewardAmount'],
            AssignmentDurationInSeconds=task['duration'],
            LifetimeInSeconds=task['lifetime'],
            AutoApprovalDelayInSeconds=604800,
            Question=questionText,
            QualificationRequirements=quals,
        )
        print(response)
    else:
        raise RuntimeError("This action is not currently enabled; set `ALLOW_HIT_CREATION` to true to proceed with this action")

# creates a HIT in the form of an External Question inside an iFrame
def create_hit_iframe(task):
    questionText = "<ExternalQuestion xmlns=\"http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/"
    questionText += "2006-07-14/ExternalQuestion.xsd\">\n<ExternalURL>" + task['taskUrl']
    questionText += "</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>"
    create_hit(task, questionText)
    
# Helper to create a HIT in the form of a simple UI with a link to an external page and an
# input box for a completion code 
def create_hit_external(task):
    with open('questionform_template.xml', 'r') as myfile:
        template=myfile.read() 
    question_xml = template % (task["title"], task["instructions"], task['taskUrl'])
    create_hit(task, question_xml)

# %%
# Use this cell to configure your HIT
dataset = 'infographics_zoomlens' # file in datasets dir (without extension)
big_name = 'Infographics'

hit_config = {
    # you probably want to change these
    "numAssignments": 120, # per HIT
    "rewardAmount": "1.25",
    "lifetime": 24 * 60 * 60, # in seconds
    # one HIT gets created per dictionary
    # you can add items to the dict to override the values above
    # alternatively, provide a number to create that many HITs with the default settings
    "HITs": 1, # DO NOT SET ABOVE 1; IF YOU CHANGE THIS TO A DICT YOU NEED TO INTEGRATE WITH THE CODE ABOVE
    # you probably do not want to change these
    "title": "Zoom Maps: " + big_name,
    "description": "Pinch and Zoom to look at " + big_name,
    "keywords": ["zoom", "pinch", "gesture", "mobile", "phone", "tablet", "image", "photo", "picture"],
    "duration": 30 * 60, # in seconds
    "taskUrl": "https://enigmatic-everglades-39931.herokuapp.com?dataset=" + dataset
}

external_submit = False # DO NOT CHANGE -- this means use iFrame
if isinstance(hit_config['HITs'], int):
    hit_config['HITs'] = [{} for i in range(hit_config['HITs'])]

# %%
# Use this cell to launch your HIT! 
hit_creation_function = create_hit_external if external_submit else create_hit_iframe

print("creating " + str(len(hit_config['HITs'])) + " HITs")
for hit_config_override in hit_config['HITs']: 
    task = copy.deepcopy(hit_config)
    task.update(hit_config_override)
    hit_creation_function(task)
# Out:
# creating 1 HITs
# {'HIT': {'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY', 'HITTypeId': '3P23GFB3B7X2SRMFBS0XHO2AAOQDBA', 'HITGroupId': '33UIGJTG3OGMX2ZCQR1ZS700VNYZ1D', 'CreationTime': datetime.datetime(2019, 4, 4, 21, 42, 14, tzinfo=tzlocal()), 'Title': 'Zoom Maps: Infographics', 'Description': 'Pinch and Zoom to look at Infographics', 'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://enigmatic-everglades-39931.herokuapp.com?dataset=infographics_zoomlens</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>', 'Keywords': 'zoom,pinch,gesture,mobile,phone,tablet,image,photo,picture', 'HITStatus': 'Assignable', 'MaxAssignments': 120, 'Reward': '1.25', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 4, 5, 21, 42, 14, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 1800, 'QualificationRequirements': [{'QualificationTypeId': '00000000000000000071', 'Comparator': 'EqualTo', 'LocaleValues': [{'Country': 'US'}], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}, {'QualificationTypeId': '000000000000000000L0', 'Comparator': 'GreaterThanOrEqualTo', 'IntegerValues': [95], 'RequiredToPreview': False, 'ActionsGuarded': 'Accept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 120, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': '615469b6-f453-4537-b9c8-b35f5dde5b82', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '615469b6-f453-4537-b9c8-b35f5dde5b82', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1265', 'date': 'Fri, 05 Apr 2019 01:42:14 GMT'}, 'RetryAttempts': 0}}

# %% [markdown]
# # HIT monitoring helpers

# %% [markdown]
# Helper functions that will be useful for monitoring the status of your HIT. See next section for how to use them.

# %%
# Contacts MTurk API to get all assignments for a HIT
# Returns them in a list. 
def get_all_assignments(hitid): 
    assignments = []
    should_continue = True
    next_token = False
    while (should_continue): 
        args = {
            'HITId': hitid, 
            'MaxResults': 100
        }
        if (next_token): 
            args['NextToken'] = next_token
        r = cl.list_assignments_for_hit(**args)
        next_token = r.get('NextToken', False)
        assignments.extend(r["Assignments"])
        should_continue = len(r["Assignments"]) > 0
    return assignments

# Summarizes all hits in `hits` in a human-readable way. 
# Prints out the HIT Title, id, if it is expired, and how many assignments it has
# completed, pending, and left for work. 
def summarize_hits(hits): 
    ret = ""
    for hit in hits: 
        expiration = hit['Expiration'].replace(tzinfo=None)
        is_expired = expiration < datetime.datetime.now()
        available = hit['NumberOfAssignmentsAvailable']
        pending = hit['NumberOfAssignmentsPending']
        approved = hit['NumberOfAssignmentsCompleted']
        completed = hit['MaxAssignments'] - available - pending - approved
        description = ("Title: {title}\n" 
        "ID: {hid}\n"
        "\tAssignments available: {left}\n"
        "\tAssignments pending: {pending}\n"
        "\tAssignments awaiting approval: {completed}\n"
        "\tAssignments completed (approved): {approved}\n"
        "\tExpired: {exp}\n\n").format(
            title=hit['Title'], 
            hid=hit['HITId'], 
            left=available, 
            pending=pending,
            completed=completed,
            approved=approved,
            exp=str(is_expired)
        )
        ret += description
    print(ret)
    
# Prints a human-readable summary of all pending/submitted/approved assignments for all hits in `hits`
def summarize_assignments(hits):
    ret = ""
    for hit in hits: 
        hid = hit['HITId']
        title =  hit['Title']
        name = "HIT %s: %s" % (hid, title)
        ret += name + "\n"
        assignments = get_all_assignments(hid)
        if len(assignments) == 0: 
            ret += "\tNo pending/submitted/approved assignments for this HIT\n"
        for a in assignments: 
            desc = "\tAssignment {aid}\n\t\tStatus: {status}\n".format(aid=a['AssignmentId'], status=a['AssignmentStatus'])
            ret += desc
    print(ret)
    
# Refreshes data about the requested hits
def get_last_n_hits(n=1, offset=0): 
    return cl.list_hits(MaxResults=(n + offset))['HITs'][offset:]

def get_hits_by_title(title, howmany=1):
    hits = []
    i = 0
    while len(hits) < howmany:
        got_hits = get_last_n_hits(10, i)
        for got_hit in got_hits:
            if got_hit['Title'] == title:
                hits.append(got_hit)
        i += 10
    return hits[:howmany]

# %% [markdown]
# # HIT monitoring

# %%
# refresh hits
hits = get_last_n_hits(100)

# %%
hits = get_hits_by_title('Zoom Maps: Infographics', 1)

# %%
# Summarizes all outstanding HITs
summarize_hits(hits)
# Out:
# Title: Zoom Maps: Infographics
# ID: 34HEO7RUG637KZS9TNQ57N6GLM9ARY
# 	Assignments available: 0
# 	Assignments pending: 0
# 	Assignments awaiting approval: 120
# 	Assignments completed (approved): 0
# 	Expired: False

# %%
# Summarizes assignments for all oustanding HITs 
summarize_assignments(hits)

# %% [markdown]
# # Approve HITs

# %% [markdown]
# Approves all outstanding assignments for the HITs displayed above.

# %%
def approve_all(hits): 
    num_approved = 0
    for hit in hits: 
        # make sure you keep getting assignments 
        assignments = get_all_assignments(hit["HITId"])
        #print(assignments)
        for a in assignments: 
            if a['AssignmentStatus'] != 'Approved':
                print("Approving assignment")
                num_approved += 1
                cl.approve_assignment(AssignmentId=a['AssignmentId'])
    print("Approved %d assignments" % num_approved)

# %%
approve_all(hits)
# Out:
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approving assignment
# Approved 120 assignments

# %% [markdown]
# # Update expiration or num tasks

# %%
# changes the expiration date on a HIT to days_from_now days in the future
def update_expiration(hitid, days_from_now): 
    if ALLOW_UPDATE_EXPIRATION: 
        days = days_from_now*datetime.timedelta(days=1)
        expire_time = datetime.datetime.now() + days

        response = cl.update_expiration_for_hit(HITId=hitid, ExpireAt=expire_time)
        print(response)
        return response
    else: 
        raise RuntimeError("This action is not currently enabled; set `ALLOW_UPDATE_EXPIRATION` to true to proceed with this action")
    
def expire_hit(hit): 
    return update_expiration(hit, -10)

# %%
def add_assignments(hitid, num_assignments): 
    if ALLOW_ASSIGNMENT_ADDITION: 
        response = cl.create_additional_assignments_for_hit(
            HITId=hitid,
            NumberOfAdditionalAssignments=num_assignments
        )
        print(response)
        return response
    else: 
        raise RuntimeError("This action is not currently enabled; set `ALLOW_ASSIGNMENT_ADDITION` to true to proceed with this action")

# %%
# Use this cell to expire a HIT 
hit_id = ''
expire_hit(hit_id)

# %%
# Use this cell to update a HIT's expiration date
hitid = ''
days_from_now = 1
update_expiration(hit_id, days_from_now)

# %%
# Use this cell to add assignments to a HIT 
hit_id = "FILL THIS IN"
num_assignments_to_add = 0
add_assignments(hit_id, num_assignments_to_add)

# %% [markdown]
# # Add custom qualifications

# %% [markdown]
# ## Add a qualification to disqualify workers who have done work before
#
# - uses "negative qualification" method from https://github.com/cloudyr/MturkR/wiki/qualifications-as-blocks
#
# #### NOTE: quals are kept separate for the sandbox and prod. Make sure you are creating and assigning your quals in prod.

# %% [markdown]
# ### Structure of a new qualification

# %%
NEW_QUAL = {
    'Name': 'qualName',
    'Keywords': ['keywords', 'for', 'qual'],
    'Description': 'What is this qual, and why are you assigning it?',
    'QualificationTypeStatus': 'Active',
    'AutoGranted': False
}

# %% [markdown]
# ### Helpers for creating, viewing, and assigning qualifications

# %%
# Registers a custom qualification with MTurk 
def create_qual(new_qual):
    if ALLOW_CREATE_QUAL:
        qual_kwargs = copy.deepcopy(new_qual)
        qual_kwargs['Keywords'] = ','.join(qual_kwargs['Keywords'])
        response = cl.create_qualification_type(**qual_kwargs)
#         print(response)
        Id = response['QualificationType']['QualificationTypeId']
        return Id
    else: 
        raise RuntimException("This action is not currently enabled; set `ALLOW_CREATE_QUAL` to true to proceed with this action")
        
# Gets all the custom quals you have created and prints them
def list_quals(): 
    response = cl.list_qualification_types(
            Query='hasCompletedVisualGraphRecallTask',
            MustBeRequestable=False
    )
    print(response)
    
# Assigns a qualification to a worker 
def assign_qual(qual_id, worker_ids): 
    for worker in worker_ids: 
        response = cl.associate_qualification_with_worker(
                QualificationTypeId=qual_id, 
                WorkerId=worker,
                IntegerValue=1,
                SendNotification=False
        )
        print(response)
        assert response
        
# Gets the ids of all workers who worked on a particular hit 
def get_workers_for_hit(hitid): 
    a = get_all_assignments(hitid)
    workers = [a_['WorkerId'] for a_ in a]
    return workers
    
# Confirms that every worker in worker_ids has qual with qual_id
def confirm_quals(qual_id, worker_ids): 
    for w in worker_ids: 
        response = cl.get_qualification_score(
                QualificationTypeId=qual_id,
                WorkerId=w
        )
        response = response['Qualification']
        assert response['Status'] == 'Granted'
        assert response['IntegerValue'] == 1
        
# Assigns qual with `qual_id` to every worker who has completed an assignment for the hit with `hitid`
def assign_qual_for_hit(hitid, qual_id): 
    workers = get_workers_for_hit(hitid)
    print("got workers")
    assign_qual(qual_id, workers)
    print("assigned qual")
    confirm_quals(qual_id, workers)
    print("confirmed qual")

# %% [markdown]
# ### Use the following cells to manipulate qualifications

# %%
# Use this cell to view the custom qualifications you have created
list_quals()
# Out:
# {'NumResults': 1, 'NextToken': 'p1:z27l+YreZcx8GA9dbYVFvssUHtkQppnDW9lspWhWu8KT+8tDK1AEQAzmc445AQ==', 'QualificationTypes': [{'QualificationTypeId': '3Q3I6L0BKOF89DJMPYQCYLJBC2VW5E', 'CreationTime': datetime.datetime(2018, 3, 23, 17, 19, 7, tzinfo=tzlocal()), 'Name': 'hasCompletedVisualGraphRecallTask', 'Description': 'Assigned to people who have already completed work on a visual graph recall task. A worker can only complete this type of task once.', 'Keywords': 'Already completed visual graph recall task', 'QualificationTypeStatus': 'Active', 'IsRequestable': True, 'AutoGranted': False}], 'ResponseMetadata': {'RequestId': '53ac8562-0d77-4b85-8241-6d21e0ea511b', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '53ac8562-0d77-4b85-8241-6d21e0ea511b', 'content-type': 'application/x-amz-json-1.1', 'content-length': '531', 'date': 'Thu, 04 Apr 2019 16:55:31 GMT'}, 'RetryAttempts': 0}}

# %%
# Use this cell to create a new qual 
qual_to_create = {}
create_qual(qual_to_create)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-12d2d86e8e9b> in <module>
#       1 # Use this cell to create a new qual
#       2 qual_to_create = {}
# ----> 3 create_qual(qual_to_create)
#
# <ipython-input-22-3c19811be851> in create_qual(new_qual)
#       9         return Id
#      10     else:
# ---> 11         raise RuntimException("This action is not currently enabled; set `ALLOW_CREATE_QUAL` to true to proceed with this action")
#      12
#      13 # Gets all the custom quals you have created and prints them
#
# NameError: name 'RuntimException' is not defined

# %%
# Use this cell to assign a custom qual to every worker who has done a specific HIT
hit_id = "FILL THIS IN"
qual_id_to_assign = "FILL THIS IN"
assign_qual_for_hit(hit_id, qual_id_to_assign)

# %% [markdown]
# # Create Compensation HIT
#
# Mistakes happen, and sometimes they can lead to a worker who put in an honest effort being unable to complete a task and get paid. It's a good idea to compensate these workers when they reach out because it helps maintain relations with workers and is the right thing to do.
#
# However, workers can only be paid upon completing a task. The workaround is to create a custom qualification, assign it to the worker you want to compensate, and create a no-work HIT requiring the custom qualification. This code does that.

# %%
# worker_ids is str[]
# compensation is str but should match the regex ^\d*\.\d\d$ (e.g. "1.00")
# for_hit_id is str -- optional, but helpful for records
def compensate_workers(worker_ids, compensation, for_hit_id=""):
    with open('compensation.xml', 'r') as myfile:
        question_xml=myfile.read()

    keywords = ['compensation']
    description = 'Compensation for HIT'
    if for_hit_id:
        keywords.append(for_hit_id)
        description += ' ' + for_hit_id

    # create qual, assign to workers
    custom_qual = {
        'Name': str(uuid4()), # a qual must have a unique name
        'Keywords': keywords,
        'Description': description,
        'QualificationTypeStatus': 'Active',
        'AutoGranted': False
    }
    qual_id = create_qual(custom_qual)
    assign_qual(qual_id, worker_ids)

    # create HIT requiring qual
    task = {
        'numAssignments': len(worker_ids),
        'lifetime': 3 * 24 * 60 * 60, # 3 days
        'duration': 5 * 60, # 5 min
        'rewardAmount': compensation,
        'title': description,
        'keywords': keywords,
        'description': description,
    }
    quals = [{
        'QualificationTypeId': qual_id,
        'Comparator': 'Exists',
        'ActionsGuarded': 'DiscoverPreviewAndAccept'
    }]
    create_hit(task, question_xml, quals)

# %%
worker_ids = ['ARHBT4K14I7U', 'A2T974CBTMP1AT', 'A3VTF0VGQ7648H'] # worker_id strings in a list
compensation = "3.00" # change to the amount of dollars you want to give
for_hit_id = "33UIGJTG3OGMX2ZCQR1ZS700VNYZ1D (#2)" # hit_id string (what you are compensating for)compensate_workers(worker_ids, compensation, for_hit_id)
compensate_workers(worker_ids, compensation, for_hit_id)
# Out:
# {'ResponseMetadata': {'RequestId': '820c9d86-f0a3-47a0-9dec-86cfec95c160', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '820c9d86-f0a3-47a0-9dec-86cfec95c160', 'content-type': 'application/x-amz-json-1.1', 'content-length': '2', 'date': 'Sat, 06 Apr 2019 01:41:51 GMT'}, 'RetryAttempts': 0}}
# {'ResponseMetadata': {'RequestId': '058d18af-af01-4cdd-908e-3902771503e2', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '058d18af-af01-4cdd-908e-3902771503e2', 'content-type': 'application/x-amz-json-1.1', 'content-length': '2', 'date': 'Sat, 06 Apr 2019 01:41:51 GMT'}, 'RetryAttempts': 0}}
# {'ResponseMetadata': {'RequestId': 'a7e0a1fc-c74f-4411-a2ab-09f9dceacadd', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'a7e0a1fc-c74f-4411-a2ab-09f9dceacadd', 'content-type': 'application/x-amz-json-1.1', 'content-length': '2', 'date': 'Sat, 06 Apr 2019 01:41:53 GMT'}, 'RetryAttempts': 0}}
# {'HIT': {'HITId': '3D1UCPY6GGI1I9ESLZ5VTYX5PM1830', 'HITTypeId': '3K9PHCH9NOSYJ8UQRESBIZT7Q1JGDV', 'HITGroupId': '3ZM82D7CCB9UN3K5XKM6NG41037ZX1', 'CreationTime': datetime.datetime(2019, 4, 5, 21, 41, 53, tzinfo=tzlocal()), 'Title': 'Compensation for HIT 33UIGJTG3OGMX2ZCQR1ZS700VNYZ1D (#2)', 'Description': 'Compensation for HIT 33UIGJTG3OGMX2ZCQR1ZS700VNYZ1D (#2)', 'Question': '<QuestionForm xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2005-10-01/QuestionForm.xsd">\n    <Overview>\n        <FormattedContent><![CDATA[\n            <h1><strong>Compensation HIT</strong></h1>\n            <h2>Description</h2>\n            <h4>We\'re sorry you experienced a problem with one of our HITs. Please accept our apologies and compensation for your time.</h4>\n            <h2>Instructions:</h2>\n            <h4>Enter your worker ID in the box below.</h4>\n        ]]>\n        </FormattedContent>\n    </Overview>\n    <Question>\n        <QuestionIdentifier>workerId</QuestionIdentifier>\n        <DisplayName>Worker ID</DisplayName>\n        <IsRequired>true</IsRequired>\n        <QuestionContent>\n            <Text>Please enter your worker ID here: </Text>\n        </QuestionContent>\n        <AnswerSpecification>\n            <FreeTextAnswer>\n                <NumberOfLinesSuggestion>1</NumberOfLinesSuggestion>\n            </FreeTextAnswer>\n        </AnswerSpecification>\n    </Question>\n</QuestionForm>\n', 'Keywords': 'compensation,33UIGJTG3OGMX2ZCQR1ZS700VNYZ1D (#2)', 'HITStatus': 'Assignable', 'MaxAssignments': 3, 'Reward': '3.00', 'AutoApprovalDelayInSeconds': 604800, 'Expiration': datetime.datetime(2019, 4, 8, 21, 41, 53, tzinfo=tzlocal()), 'AssignmentDurationInSeconds': 300, 'QualificationRequirements': [{'QualificationTypeId': '3UZ6VZ89OT5E17AVB3D7F4XFSCUBG2', 'Comparator': 'Exists', 'RequiredToPreview': True, 'ActionsGuarded': 'DiscoverPreviewAndAccept'}], 'HITReviewStatus': 'NotReviewed', 'NumberOfAssignmentsPending': 0, 'NumberOfAssignmentsAvailable': 3, 'NumberOfAssignmentsCompleted': 0}, 'ResponseMetadata': {'RequestId': 'e5e8599e-2724-44e0-b439-945247d77c6b', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'e5e8599e-2724-44e0-b439-945247d77c6b', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1914', 'date': 'Sat, 06 Apr 2019 01:41:53 GMT'}, 'RetryAttempts': 0}}

# %% [markdown]
# # Download data

# %% [markdown]
# Helper to download data from MTurk

# %%
def pretty_print(obj):
    pp = pprint.PrettyPrinter(indent=4)
    pp.pprint(obj)
    pp = None

# Downloads all the assignments completed for `hits` as a list of dictionaries. 
# If a download_path is given, also saves that data as json 
def get_assignment_content(hits, download_path="", should_print=False): 
    all_responses = []
    for hit in hits: 
        hitid = hit['HITId']
        assignments = get_all_assignments(hitid)
        for a in assignments:
            a_xml = a['Answer']
            #print(a_xml)
            soup = bs(a_xml, "html.parser")
            answers = soup.find_all("answer")
            #print(answers)
            results = {'HITId': a['HITId'], 'AssignmentId': a['AssignmentId'], 'WorkerId': a['WorkerId']}
            for ans in answers: 
                identifier = ans.find('questionidentifier').string
                answer = ans.find('freetext').string
                try: 
                    results[identifier] = json.loads(answer)
                except:
                    results[identifier] = answer
            all_responses.append(results)
    if should_print: 
        pretty_print(all_responses)
    if download_path: 
        with open(download_path, 'w') as outfile: 
            json.dump(all_responses, outfile)
    return all_responses

# %%
# Use this cell to download data
SAVE_PATH = '../../zoommaps-analysis/results/infographics_zoomlens/mturk-infographics_zoomlens.json'
responses = get_assignment_content(hits, download_path=SAVE_PATH, should_print=True)
# Out:
# [   {   'AssignmentId': '3BXQMRHWK083PCR9KMGG98KMBEAUM4',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AKEWR9CC1QJ00',
#         'userId': '5ca6b29684a4aa0017232f3d'},
#     {   'AssignmentId': '3JBT3HLQF9CQWEIWIP7G74TWI10ZPU',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2HFBFZEJLIGBG',
#         'userId': '5ca6b2a984a4aa0017232f48'},
#     {   'AssignmentId': '37TD41K0AIJA1DNEISR2RBXMW3LSC4',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3GZVH1LI90MBD',
#         'userId': '5ca6b32e84a4aa0017232f78'},
#     {   'AssignmentId': '3FFJ6VRIL2Y1D7P21044S8PYEHN0IU',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'ASI6KXF2GAUTQ',
#         'userId': '5ca6b30384a4aa0017232f63'},
#     {   'AssignmentId': '3R0T90IZ1TM7B8ENNSXL2XEJ8TSCG7',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1B5Q9WUNIT5GV',
#         'userId': '5ca6b3ab84a4aa0017232fa8'},
#     {   'AssignmentId': '3MAOD8E57RK1OY641S636U8QAM1XNZ',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'ADEJRLH44KOJC',
#         'userId': '5ca6b37d84a4aa0017232f91'},
#     {   'AssignmentId': '33LK57MYLUFN96YOA6BA29Y75L7ZSA',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AXFTXWW2B0Y5B',
#         'userId': '5ca6b2ca84a4aa0017232f52'},
#     {   'AssignmentId': '3ON104KXQL60DQR89IVL52OJA414WL',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2R9MIRIP29431',
#         'userId': '5ca6b2aa84a4aa0017232f49'},
#     {   'AssignmentId': '3YMU66OBIOIYSGP39KBMDOBZLLXHGL',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A24R73JBDOGBGH',
#         'userId': '5ca6b3c284a4aa0017232fb3'},
#     {   'AssignmentId': '3LUY3GC630A7C4CQZUFXGK0X89PP7W',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2KSRZNL9HC7UM',
#         'userId': '5ca6b56184a4aa00172330ad'},
#     {   'AssignmentId': '3H8DHMCCWALMIMGKDFDBKVOU0ALDKB',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A25I110YXT1QRA',
#         'userId': '5ca6b34884a4aa0017232f7f'},
#     {   'AssignmentId': '3HFNH7HEMIOB59O6SAYGM230C7SQGN',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1SCLZJMXYG630',
#         'userId': '5ca6b29384a4aa0017232f3b'},
#     {   'AssignmentId': '3QECW5O0KIBQHSRESI9KNANY65DT5M',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2XQ3P6M9NZNYB',
#         'userId': '5ca6b2e984a4aa0017232f5b'},
#     {   'AssignmentId': '3M23Y66PO3HLLWED81EZ5B5C0HAS6C',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1N53V41FMCR7Q',
#         'userId': '5ca6b28784a4aa0017232f36'},
#     {   'AssignmentId': '3YMTUJH0DTQ8L9NEEDQAIIHK6AJ4TV',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2LV5432PV1S39',
#         'userId': '5ca6b2ab84a4aa0017232f4b'},
#     {   'AssignmentId': '3OXV7EAXLF0H1FTYIMDYX3X082E360',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1QYGPU1NDUMWW',
#         'userId': '5ca6b5b984a4aa00172330e0'},
#     {   'AssignmentId': '34J10VATJG8P10U1IYYJ7EGGRKKQIF',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2AGQGMZVSZVUJ',
#         'userId': '5ca6b2a184a4aa0017232f44'},
#     {   'AssignmentId': '33JKGHPFYD4QUM70NL4UVDSS3IHNM5',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A141N2XGQXKPME',
#         'userId': '5ca6b29284a4aa0017232f3a'},
#     {   'AssignmentId': '3PPTZCWALRUBWQJBI2M579J6NYPQZH',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A30XJHY5V549VC',
#         'userId': '5ca6b73f84a4aa00172331e5'},
#     {   'AssignmentId': '3FIUS151DWCKSKUSPET4SOZY6LMGGN',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3OVS29S2TYBQR',
#         'userId': '5ca6b63d84a4aa0017233138'},
#     {   'AssignmentId': '3GFK2QRXXARI99V8NNEVAUUXA0W5WR',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2OPV173ISAT0D',
#         'userId': '5ca6b31b84a4aa0017232f73'},
#     {   'AssignmentId': '3ZGVPD4G6UROO6B3Z6G0CEUT74LZTZ',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'ALUPYZR6LW0QF',
#         'userId': '5ca6b2b084a4aa0017232f4d'},
#     {   'AssignmentId': '3ZQIG0FLQFQZ73ANTEW8ESOWNO0WVR',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2C27YTQSQ1GXS',
#         'userId': '5ca6b6b584a4aa001723319a'},
#     {   'AssignmentId': '333U7HK6IAPR72A2VUDZJGOHLLODJF',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A10AUPF8B5NJPC',
#         'userId': '5ca6b76484a4aa00172331fb'},
#     {   'AssignmentId': '3QUO65DNQVYRPFCLX2VT1C9R6FSOUI',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2090SRVQLWA3F',
#         'userId': '5ca6b6a684a4aa001723318f'},
#     {   'AssignmentId': '3PMBY0YE28DSWYRF9MRBAGSW4GZ9CF',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AS1KP4SMNONQC',
#         'userId': '5ca6b62b84a4aa0017233133'},
#     {   'AssignmentId': '3UNH76FOCTFK6LBEUND5CTQZ73NMYY',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2JJ3531QBNT5K',
#         'userId': '5ca6b54e84a4aa00172330a5'},
#     {   'AssignmentId': '3MRNMEIQW6GX2SY2YFPCZV19PASDLG',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AGRKG3YT3KMD8',
#         'userId': '5ca6b64484a4aa0017233140'},
#     {   'AssignmentId': '3GGAI1SQEW873IA9YVVGF2YG4F4MCP',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1TMF8Z3VT364E',
#         'userId': '5ca6b3bc84a4aa0017232fb1'},
#     {   'AssignmentId': '3CFJTT4SXU0FVIPMMZPD7NZLMVTI7C',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1XMA0AODEQF1J',
#         'userId': '5ca6b40884a4aa0017232fd5'},
#     {   'AssignmentId': '3HMVI3QICK2NAWPP11U7S12W9SSY12',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A7P3R1AIA4TVV',
#         'userId': '5ca6b57384a4aa00172330b7'},
#     {   'AssignmentId': '3E1QT0TDFQJJVWU5W4HJLNVGXF28IS',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A47A33P2IOMAO',
#         'userId': '5ca6b72f84a4aa00172331da'},
#     {   'AssignmentId': '3GS6S824SR7MZY1ERNAH4BUJ1LXNW0',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3RV83RAJFBIVU',
#         'userId': '5ca6b59284a4aa00172330c7'},
#     {   'AssignmentId': '3Q8GYXHFEQC9VBP36WEUY0NUIKG5CK',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2D6IP0ICXG4H8',
#         'userId': '5ca6b5a084a4aa00172330d1'},
#     {   'AssignmentId': '3TVSS0C0E2AKUB6YOJWTDA0BQ3JWTA',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1QYTV4R5UWV4G',
#         'userId': '5ca6b52584a4aa0017233092'},
#     {   'AssignmentId': '37W3JXSD67IGBX5SYPJSLRSQ552WY0',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1YAV6M4OHT9TS',
#         'userId': '5ca6b6b884a4aa001723319c'},
#     {   'AssignmentId': '3AMYWKA6YCW6N4MK1KXQL6VB3TBO6H',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'ATY1UPL3PAABG',
#         'userId': '5ca6b8a384a4aa00172332cc'},
#     {   'AssignmentId': '3IO1LGZLKA732CZ4U38UOK5BOO586W',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AW1QY7Q83DYCJ',
#         'userId': '5ca6b46884a4aa001723301e'},
#     {   'AssignmentId': '3JPSL1DZ5T9PSLYBQIEPMMXS92VAND',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2U9RB3NP8F63K',
#         'userId': '5ca6b5b184a4aa00172330da'},
#     {   'AssignmentId': '39K0FND3AIPJA3DBEHZP978S4CLMAP',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AFUEPFQCGULSS',
#         'userId': '5ca6b66284a4aa0017233155'},
#     {   'AssignmentId': '3DH6GAKTYZZK5SAX9C3ZKVM8M77YZT',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A17CM9QPETQYGH',
#         'userId': '5ca6b8ed84a4aa00172332f9'},
#     {   'AssignmentId': '3TXWC2NHN0083FGB68HBPLWEQJLS9S',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'ATPESQAKH55FM',
#         'userId': '5ca6b6ed84a4aa00172331b7'},
#     {   'AssignmentId': '3PDJHANYK6QWVN0XX7201XYAR7WH6L',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1NQBLUXICRGG6',
#         'userId': '5ca6b66484a4aa0017233159'},
#     {   'AssignmentId': '36TFCYNS45K9E2KTYUBQ1ABUOBVHXF',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A17GM8X15U2WW6',
#         'userId': '5ca6b6bd84a4aa001723319d'},
#     {   'AssignmentId': '3OWEPKL08AM79J0DJF25CVV28UPN7Z',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A6BQI17SMDXGE',
#         'userId': '5ca6b68884a4aa001723316d'},
#     {   'AssignmentId': '369J354OFEKIVR5MD1KIGXM9C7J6GB',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3HG2T5MWSS4VQ',
#         'userId': '5ca6b63f84a4aa001723313b'},
#     {   'AssignmentId': '32VNZTT0A8EV5UAMAOLFI3G2IPQR49',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1EJ4HA4K85PBJ',
#         'userId': '5ca6ba3e84a4aa00172333c9'},
#     {   'AssignmentId': '33NF62TLXKCZL8GCNBZMNTJ75UMJKZ',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3AO6M3YRN6PVV',
#         'userId': '5ca6b96584a4aa001723334e'},
#     {   'AssignmentId': '3DOCMVPBTOOWC4S0ZMJU8SHS89VNNB',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3JGVZEXXELM3C',
#         'userId': '5ca6b86484a4aa00172332a2'},
#     {   'AssignmentId': '3KKG4CDWKJ8P1UE0G7LTRIG8C3N492',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1ZJQUUZ9LYLD1',
#         'userId': '5ca6bbb284a4aa001723346d'},
#     {   'AssignmentId': '3IOEN3P9S8TLRCFJVIZF9AI3AIY164',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1LHF4WBGMP1RE',
#         'userId': '5ca6b98584a4aa0017233363'},
#     {   'AssignmentId': '3634BBTX0P4SAB4S4INPVFC2KJHFII',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3COC0549IQF4N',
#         'userId': '5ca6ba8b84a4aa00172333e5'},
#     {   'AssignmentId': '3NAPMVF0ZXPBKXBKXW4LK7S4XZ327S',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3TOI40R1LPLNE',
#         'userId': '5ca6bbff84a4aa0017233481'},
#     {   'AssignmentId': '3AAJC4I4FH2UA3FYNC2WA87K932JZO',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A247PDSKLZU86P',
#         'userId': '5ca6bc4184a4aa001723349d'},
#     {   'AssignmentId': '3WSELTNVR4CNNY3VNE01VL3KYKMATJ',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AN7N56XWXCX45',
#         'userId': '5ca6bc9d84a4aa00172334cd'},
#     {   'AssignmentId': '35BLDD71I7731YFS41GFDWIE4Q7VZJ',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A39JP668VJ7RG5',
#         'userId': '5ca6bacc84a4aa0017233405'},
#     {   'AssignmentId': '33IZTU6J82BY4BY99ONP5OIWXMGSXF',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1NCSZCN8EA787',
#         'userId': '5ca6bbe684a4aa001723347d'},
#     {   'AssignmentId': '3SBEHTYCWODYA2LN98FDK0JIQT1YIQ',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3U6OXFPUOCIV2',
#         'userId': '5ca6baca84a4aa0017233403'},
#     {   'AssignmentId': '3IXQG4FA2U89MTZ9VMVGZWMEMV29BB',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1198W1SPF1R4',
#         'userId': '5ca6ba5184a4aa00172333cf'},
#     {   'AssignmentId': '3YZ8UPK3VUWQGQFI7XM26CFAH1FCUF',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A37LQHDHZLKVCH',
#         'userId': '5ca6bec484a4aa001723359e'},
#     {   'AssignmentId': '3YMU66OBIOIYSGP39KBMDOBZLL5HGT',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3SIYZQYIHULPB',
#         'userId': '5ca6bea084a4aa0017233593'},
#     {   'AssignmentId': '3MRNMEIQW6GX2SY2YFPCZV19PAXDLL',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'ABR0QB3H49635',
#         'userId': '5ca6bd5284a4aa0017233522'},
#     {   'AssignmentId': '3MD9PLUKKJOQTT6J2AUO3FO1IN8ZN9',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1C19XPG91AIXX',
#         'userId': '5ca6c08084a4aa0017233604'},
#     {   'AssignmentId': '31LM9EDVOM20TE1FKOR2FL0BZPWJN9',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A36X6B6HXD442I',
#         'userId': '5ca6c0bf84a4aa0017233610'},
#     {   'AssignmentId': '38BQUHLA9XA8C77CO047A2SXTTWOMX',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2ZL41YMY57GMT',
#         'userId': '5ca6c32384a4aa001723367c'},
#     {   'AssignmentId': '3BDCF01OGY4003TTUBCQCGBA7Y5YLG',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3TWLVMCJTH2AV',
#         'userId': '5ca6c2a184a4aa001723366d'},
#     {   'AssignmentId': '308XBLVESJEFQTVVP3V2QHM8SHDBR5',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3VLHYQMLNOUL7',
#         'userId': '5ca6c3bf84a4aa0017233696'},
#     {   'AssignmentId': '3EO896NRAX5YOR6ZHKDEOK63O7JJTB',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3SHQSYLS33U01',
#         'userId': '5ca6c41b84a4aa00172336a8'},
#     {   'AssignmentId': '31QTRG6Q2UNQRO8RM35XTXKUC87PY6',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AISNLDPD2DFEG',
#         'userId': '5ca6c55084a4aa00172336ee'},
#     {   'AssignmentId': '3CFJTT4SXU0FVIPMMZPD7NZLMV3I7M',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1ODA3Q5H6HTDQ',
#         'userId': '5ca6c49384a4aa00172336c2'},
#     {   'AssignmentId': '3L0KT67Y8FQN4GOJEK9RO2P5ZSDYSU',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3966FJUQFM8N7',
#         'userId': '5ca6c2d284a4aa0017233672'},
#     {   'AssignmentId': '31UV0MXWNRM08EB3Y6AG93LPVP95IV',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AFE042TKUI1PJ',
#         'userId': '5ca6c69b84a4aa0017233738'},
#     {   'AssignmentId': '3X3OR7WPZ0ALLX2BH7EWD3N8EJ2L8P',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3CTPF03CRIP67',
#         'userId': '5ca6c3e584a4aa001723369b'},
#     {   'AssignmentId': '3CTOC39K380BQT9S4HADJOELZAS7JN',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2H4GGKLZ4VKYL',
#         'userId': '5ca6c46084a4aa00172336b9'},
#     {   'AssignmentId': '3XUHV3NRVL80CJ0JSOSV9RKAVCVH5F',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1OF4I9WDMF2ER',
#         'userId': '5ca6c77784a4aa001723376f'},
#     {   'AssignmentId': '3IQ1VMJRYUU43JUHP8VK4L284DMA9M',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1CUK9RG3RW1DY',
#         'userId': '5ca6c44d84a4aa00172336b4'},
#     {   'AssignmentId': '3TMSXRD2X7AJLRUPM0CJ74HGYK3W1C',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2E1GFP20P78GY',
#         'userId': '5ca6c99084a4aa0017233820'},
#     {   'AssignmentId': '37UQDCYH6Y5KHO9ML6OWMCPFUX0V7X',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2CP7U2TMVJUX2',
#         'userId': '5ca6c69984a4aa0017233737'},
#     {   'AssignmentId': '39N5ACM9HFXBQN0JERDHUGR33ZMP9H',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2LT8038UCK2YH',
#         'userId': '5ca6c7a784a4aa0017233781'},
#     {   'AssignmentId': '3KKG4CDWKJ8P1UE0G7LTRIG8C3U94E',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2OK2IR4FI636Y',
#         'userId': '5ca6cd2e84a4aa00172338b3'},
#     {   'AssignmentId': '3EICBYG6456H2A4OVYIOZA6Z0LMCJO',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1UU94QSY8WVQD',
#         'userId': '5ca6cad484a4aa0017233858'},
#     {   'AssignmentId': '3Z3ZLGNNSJ4ABXCIXVRW38ER8323Q9',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2TZ97B3PWRSFL',
#         'userId': '5ca6cd1484a4aa00172338ac'},
#     {   'AssignmentId': '31EUONYN2WDR2U1L2S5YXYBAKMCVOP',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3JJ300BNH2VEG',
#         'userId': '5ca6cd8f84a4aa00172338be'},
#     {   'AssignmentId': '3O6CYIULEEBZUOLNOOM3I6MD9H2WUD',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A29TVF5RRKRF2P',
#         'userId': '5ca6ce6a84a4aa00172338ef'},
#     {   'AssignmentId': '3NAPMVF0ZXPBKXBKXW4LK7S4XZB270',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'ANQF0LHVK1236',
#         'userId': '5ca6d14b84a4aa0017233973'},
#     {   'AssignmentId': '3MTMREQS4WSFFF7PIJ5CI5AJ2EAWA1',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1QLOVE2J07QO5',
#         'userId': '5ca6cdc284a4aa00172338cd'},
#     {   'AssignmentId': '3VAR3R6G1QBTRI58UZUO5KR29ODO8F',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A4V8ED75ZKAWA',
#         'userId': '5ca6d30f84a4aa00172339ac'},
#     {   'AssignmentId': '369J354OFEKIVR5MD1KIGXM9C7WG6Y',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'ACRMN0ZH8OL5K',
#         'userId': '5ca6d32384a4aa00172339af'},
#     {   'AssignmentId': '31IBVUNM9T9XWHOS3PM8A42WSLNFVP',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1U7IFPOFUBEJC',
#         'userId': '5ca6d2e884a4aa00172339a4'},
#     {   'AssignmentId': '3OJSZ2ATDT63JUU7FF6JIEVGH94576',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'APCVD1Y1UE7XM',
#         'userId': '5ca6d6b484a4aa0017233a16'},
#     {   'AssignmentId': '32EYX73OY1JUMS41PUCXV7EWH2OUR9',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1NT4U196257LC',
#         'userId': '5ca6d86d84a4aa0017233a40'},
#     {   'AssignmentId': '3M0BCWMB8W6KYPCHOX58DGUPKWZWB0',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AUP57V7ANC664',
#         'userId': '5ca6d75484a4aa0017233a2a'},
#     {   'AssignmentId': '3JWH6J9I9TNUBV33WWELHXHYRKUBNN',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3ACX99H78WTEK',
#         'userId': '5ca6d5e284a4aa00172339f8'},
#     {   'AssignmentId': '3PWWM24LHT8FKBG371WRY7OZ8JO28U',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A28PWFKQE9VESC',
#         'userId': '5ca6ddc084a4aa0017233af4'},
#     {   'AssignmentId': '3SITXWYCNWJZNPH7Y21UFZ8WTY8XBX',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'ACZC9ZJROQZO9',
#         'userId': '5ca6dce384a4aa0017233ae0'},
#     {   'AssignmentId': '3W92K5RLWVR5UKV3XD9ZOSBJ3RFV5S',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A348HL60ZO7SNO',
#         'userId': '5ca6e00a84a4aa0017233b33'},
#     {   'AssignmentId': '3OS4RQUCRAPIN3QMY8V89S8PPTEFBQ',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1A8PV8UU5MFOA',
#         'userId': '5ca6dec184a4aa0017233b10'},
#     {   'AssignmentId': '3WZ36BJEV4QS688NTS0XQWNQG2OTBE',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2169P51P2FX79',
#         'userId': '5ca6e17184a4aa0017233b59'},
#     {   'AssignmentId': '39RP059MEI3OTDI3KVZL4ISYMUTBMW',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AQE6U75SJ92WX',
#         'userId': '5ca6e1c984a4aa0017233b5f'},
#     {   'AssignmentId': '3HUTX6F6VVXI533JEILNVTEZNOV2O0',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3VTE4HGX7CPW1',
#         'userId': '5ca6e17b84a4aa0017233b5b'},
#     {   'AssignmentId': '33PPO7FECWPVCRQWDCSZ7F9H86MIDV',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AR376H1OE6Z0S',
#         'userId': '5ca6e49484a4aa0017233bfa'},
#     {   'AssignmentId': '3AAJC4I4FH2UA3FYNC2WA87K93JZJL',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3LMXV4SZ33HPR',
#         'userId': '5ca6e13484a4aa0017233b51'},
#     {   'AssignmentId': '3TE3O85731IL2GVZ6A2RPOJ4YBER2X',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3NPLNYOYWPUZ3',
#         'userId': '5ca6e0df84a4aa0017233b4a'},
#     {   'AssignmentId': '3L70J4KAZHWG697Y1O0MQHLYVYHADJ',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1RKYF7V3KEIT4',
#         'userId': '5ca6e28884a4aa0017233b86'},
#     {   'AssignmentId': '3OONKJ5DKDTCTG3FXBEYWMH3HUABOD',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1W05VIMCTJLDP',
#         'userId': '5ca6e57184a4aa0017233c2e'},
#     {   'AssignmentId': '3TEM0PF1Q67K5W9G9M3T1B9LMC5D0V',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1IWIYSL06LQC2',
#         'userId': '5ca6e3c784a4aa0017233bd7'},
#     {   'AssignmentId': '3U5JL4WY5LJF2QWYJNR77L2QJ6Y4X5',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A4CGAGSK8P1Z1',
#         'userId': '5ca6e4cc84a4aa0017233c00'},
#     {   'AssignmentId': '3OB0CAO74IZYE7A33QXSKOI3QHHHYD',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1B84JJ7ATWVJA',
#         'userId': '5ca6ed4884a4aa0017233ce6'},
#     {   'AssignmentId': '3PWWM24LHT8FKBG371WRY7OZ8JX829',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A6WVUYVVBEXB',
#         'userId': '5ca6f00b84a4aa0017233cfe'},
#     {   'AssignmentId': '3C6FJU71TR33JTGN3P4R337TKPJYUV',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2RMR0ZSQ575XZ',
#         'userId': '5ca6ef4884a4aa0017233cf6'},
#     {   'AssignmentId': '30OG32W0SVLSIYFN6NGBI5NJUHONEG',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AVNAS64N7102H',
#         'userId': '5ca6f5f984a4aa0017233d9e'},
#     {   'AssignmentId': '3M68NM076IH9KHE0TCEUF10GEGO6R1',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1154EZYFNAZUS',
#         'userId': '5ca6f8d984a4aa0017233dd5'},
#     {   'AssignmentId': '36V4Q8R5ZLABXJKS3DWBZ7NX8U3MQS',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'AXQDSQGBC79S2',
#         'userId': '5ca6f8cf84a4aa0017233dd3'},
#     {   'AssignmentId': '3U088ZLJVL3JE297QH8JTZY6TSKW0W',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A3MWDD6PZZ9SM3',
#         'userId': '5ca6fb3284a4aa0017233dfd'},
#     {   'AssignmentId': '34YB12FSQZYKKUQE0HRZ5TJV28WMG1',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2I78PUZX45G3X',
#         'userId': '5ca6fdcf84a4aa0017233e1d'},
#     {   'AssignmentId': '39DD6S19JQLMZNT69BR5DSUS4W1EZV',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1PZIN8H1VI6SY',
#         'userId': '5ca701c484a4aa0017233e67'},
#     {   'AssignmentId': '3HWRJOOET6CPYB7SEJXXHZXPHH2SE5',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2SFVXYGYSC4VU',
#         'userId': '5ca707d984a4aa0017233ec6'},
#     {   'AssignmentId': '30LB5CDZNDKN8XEC14SQS3SOAVV0ZZ',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A16QJWRA538JC',
#         'userId': '5ca70d4784a4aa0017233ed4'},
#     {   'AssignmentId': '3TR2532VIQ4SMTVNL75LDAEP405J6Z',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A2ROUAYT2602ZS',
#         'userId': '5ca70f4e84a4aa0017233ee4'},
#     {   'AssignmentId': '3DL65MZB8EP9RUIWHX7X2UT7VE4CEJ',
#         'HITId': '34HEO7RUG637KZS9TNQ57N6GLM9ARY',
#         'WorkerId': 'A1ZY2UA462KD1T',
#         'userId': '5ca72ecf84a4aa0017233f2b'}]

# %%
list(filter(lambda r: r['WorkerId'] == 'A15340BRCER2UO', responses))
# Out:
# []
